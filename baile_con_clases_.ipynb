# %% [markdown]
# <a href="https://colab.research.google.com/github/Trodriguez238/PROGCOM-B/blob/main/baile_con_clases_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clase base
class PasoBase:
    def ejecutar(self):
        print("Inicio de la coreografía")

# Cada paso hereda del anterior
class PoseInicial(PasoBase):
    def ejecutar(self):
        super().ejecutar()
        print("estamos todos tiesos")

class MovimientoPiernas(PoseInicial):
    def ejecutar(self):
        super().ejecutar()
        print("todos hacemos paso cruzado con la pierna izquierda alfrente")
        print("todos alzamos la pierna derecha y alzamos brazos")
        print("todos hacemos paso cruzado con la pierna izquierda atras bajando brazos")
        print("todos hacemos paso cruzado alfrente alando brazos")

class PatadaCorta(MovimientoPiernas):
    def ejecutar(self):
        super().ejecutar()
        print("todos hacemos una patada hacia adelante alzando la pierna izquierda, con el brazo derecho doblado y extendiendo el brazo derecho hacia la izquierda")

class Pasito(PatadaCorta):
    def ejecutar(self):
        super().ejecutar()
        print("pasito a la derecha")
        print("pasito hacia la izquierda")

class PatadaPuno(Pasito):
    def ejecutar(self):
        super().ejecutar()
        print("patada")
        print("lanzar el puño")

class GirarCabeza(PatadaPuno):
    def ejecutar(self):
        super().ejecutar()
        print("cruzar las piernas con los brazos abiertos")
        print("girar la cabeza a la derecha")

class Paso7(GirarCabeza):
    def ejecutar(self):
        super().ejecutar()
        print("Pasito a la derecha")
        print("Pasito a la izquierda")

class Paso8(Paso7):
    def ejecutar(self):
        super().ejecutar()
        print("cierro las piernas")
        print("abro las piernas")

class Paso9(Paso8):
    def ejecutar(self):
        super().ejecutar()
        print("Levanto el brazo derecho y la pierna izquierda")

class PasitoIzq(Paso9):
    def ejecutar(self):
        super().ejecutar()
        print("saltico a la derecha hacia adelante")
        print("pasito a la izquierda hacia adelante")

class Meneadito(PasitoIzq):
    def ejecutar(self):
        super().ejecutar()
        print("pasito a la derecha")
        print("pasito a la izquierda")
        print("mueve cadera")

class Hulk(Meneadito):
    def ejecutar(self):
        super().ejecutar()
        print("sube y abre brazos")
        print("baja y cruza brazos")

# Clase que ejecuta toda la coreografía
class CoreografiaCompleta(Hulk):
    def ejecutar(self):
        print("🎶 Iniciando la coreografía completa 🎶")
        super().ejecutar()
        print("🎶 Fin de la coreografía 🎶")

# %%
# --- Definición de clases ---
class PasoBase:
    def ejecutar(self):
        print("Inicio de la coreografía")

class PoseInicial(PasoBase):
    def ejecutar(self):
        super().ejecutar()
        print("estamos todos tiesos")

class MovimientoPiernas(PoseInicial):
    def ejecutar(self):
        super().ejecutar()
        print("todos hacemos paso cruzado con la pierna izquierda alfrente")
        print("todos alzamos la pierna derecha y alzamos brazos")
        print("todos hacemos paso cruzado con la pierna izquierda atras bajando brazos")
        print("todos hacemos paso cruzado alfrente alando brazos")

class PatadaCorta(MovimientoPiernas):
    def ejecutar(self):
        super().ejecutar()
        print("todos hacemos una patada hacia adelante alzando la pierna izquierda, con el brazo derecho doblado y extendiendo el brazo derecho hacia la izquierda")

class Pasito(PatadaCorta):
    def ejecutar(self):
        super().ejecutar()
        print("pasito a la derecha")
        print("pasito hacia la izquierda")

class PatadaPuno(Pasito):
    def ejecutar(self):
        super().ejecutar()
        print("patada")
        print("lanzar el puño")

class GirarCabeza(PatadaPuno):
    def ejecutar(self):
        super().ejecutar()
        print("cruzar las piernas con los brazos abiertos")
        print("girar la cabeza a la derecha")

class Paso7(GirarCabeza):
    def ejecutar(self):
        super().ejecutar()
        print("Pasito a la derecha")
        print("Pasito a la izquierda")

class Paso8(Paso7):
    def ejecutar(self):
        super().ejecutar()
        print("cierro las piernas")
        print("abro las piernas")

class Paso9(Paso8):
    def ejecutar(self):
        super().ejecutar()
        print("Levanto el brazo derecho y la pierna izquierda")

class PasitoIzq(Paso9):
    def ejecutar(self):
        super().ejecutar()
        print("saltico a la derecha hacia adelante")
        print("pasito a la izquierda hacia adelante")

class Meneadito(PasitoIzq):
    def ejecutar(self):
        super().ejecutar()
        print("pasito a la derecha")
        print("pasito a la izquierda")
        print("mueve cadera")

class Hulk(Meneadito):
    def ejecutar(self):
        super().ejecutar()
        print("sube y abre brazos")
        print("baja y cruza brazos")

class CoreografiaCompleta(Hulk):
    def ejecutar(self):
        print("🎶 Iniciando la coreografía completa 🎶")
        super().ejecutar()
        print("🎶 Fin de la coreografía 🎶")

# --- Ejecución ---
if __name__ == "__main__":
    coreografia = CoreografiaCompleta()
    coreografia.ejecutar()
# Out:
# 🎶 Iniciando la coreografía completa 🎶
# Inicio de la coreografía
# estamos todos tiesos
# todos hacemos paso cruzado con la pierna izquierda alfrente
# todos alzamos la pierna derecha y alzamos brazos
# todos hacemos paso cruzado con la pierna izquierda atras bajando brazos
# todos hacemos paso cruzado alfrente alando brazos
# todos hacemos una patada hacia adelante alzando la pierna izquierda, con el brazo derecho doblado y extendiendo el brazo derecho hacia la izquierda
# pasito a la derecha
# pasito hacia la izquierda
# patada
# lanzar el puño
# cruzar las piernas con los brazos abiertos
# girar la cabeza a la derecha
# Pasito a la derecha
# Pasito a la izquierda
# cierro las piernas
# abro las piernas
# Levanto el brazo derecho y la pierna izquierda
# saltico a la derecha hacia adelante
# pasito a la izquierda hacia adelante
# pasito a la derecha
# pasito a la izquierda
# mueve cadera
# sube y abre brazos
# baja y cruza brazos
# 🎶 Fin de la coreografía 🎶

# %%
class SoloPatadaCorta(PatadaCorta):
    def ejecutar(self):
        print("todos hacemos una patada hacia adelante alzando la pierna izquierda, con el brazo derecho doblado y extendiendo el brazo derecho hacia la izquierda")

# Ejemplo de uso
if __name__ == "__main__":
    paso = SoloPatadaCorta()
    paso.ejecutar()
# Out:
# todos hacemos una patada hacia adelante alzando la pierna izquierda, con el brazo derecho doblado y extendiendo el brazo derecho hacia la izquierda
